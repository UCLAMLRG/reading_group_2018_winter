# %%
import numpy as np
import pandas as pd

# %%
# load data from Dressel & Farid (2018)
tab = pd.read_csv('./BROWARD_CLEAN_SUBSET.csv')
charge_tab = pd.read_csv('./CHARGE_ID.csv')

# %%
tab[:5]
# Out:
#    block_num     id  race  sex  age  juv_fel_count  juv_misd_count  \
# 0          1   8307     2    1   53              0               0
# 1          1  10406     2    0   43              0               0
# 2          1   8267     2    0   46              0               0
# 3          1   5593     1    0   37              0               0
# 4          1     61     2    1   51              0               0
#
#    priors_count  charge_id  charge_degree (misd/fel)  compas_decile_score  \
# 0             5        413                         1                    6
# 1             2        306                         1                    7
# 2             3        371                         1                    3
# 3             4         21                         0                    4
# 4             7        306                         1                    2
#
#    two_year_recid
# 0               0
# 1               0
# 2               1
# 3               1
# 4               0

# %%
c = charge_tab[charge_tab['charge_id'] == 413]
c['mturk_charge_name'].iloc[0]
# Out:
# 'Unlicensed Telemarketing'

# %%
# dictionary of keys
race = {1:"white", 2:"black",3:"hispanic", 4:"Asian", 5:"Native American", 6:"Other"}
gender = { 0:"male", 1:"female"}
charge_degree = {0: "misdemeanor", 1: "felony"}
recid = {0:"no",1: "yes"}

# %%
# randomly select 20 people
np.random.seed(seed=100) # set the same seed each time so this is repeatable
arr = np.random.randint(size=20,low=0,high=999)
print(arr)
n = 1
for i in arr:
    charge_str = charge_tab[charge_tab['charge_id'] == tab['charge_id'].iloc[i]]['mturk_charge_name'].iloc[0]
    age_str = str(tab['age'].iloc[i])
    deg = charge_degree[tab['charge_degree (misd/fel)'].iloc[i]]
    #print((gender[tab['sex'].iloc[i]],age_str,charge_str))
    #print("The defendant is a %s aged %s. They have been charged with: %s." +\ )
    print('Question '+str(n))
    print("The defendant is a %s aged %s. They have been charged with: %s. This crime is classified as a %s. They have been convicted of %s prior crimes. They have %s juvenile felony charges and %s juvenile misdemeanor charges on their record.\n" % 
          (gender[tab['sex'].iloc[i]],age_str,charge_str,deg,tab['priors_count'].iloc[i],tab['juv_fel_count'].iloc[i],tab['juv_misd_count'].iloc[i]) )
    print("Do you think this person will commit another crime within 2 years? ")
    print(recid[tab['two_year_recid'].iloc[i]])
    print("This person's race is: "+race[tab['race'].iloc[i]])
    print("")
    n = n+1
# Out:
# [520 792 835 871 855  79 944 906 350 948 866  53 578 738 526 802 752 280
#  655 228]
# Question 1
# The defendant is a male aged 26. They have been charged with: Burglary. This crime is classified as a felony. They have been convicted of 6 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: black
#
# Question 2
# The defendant is a male aged 42. They have been charged with: Possession of Cocaine. This crime is classified as a felony. They have been convicted of 3 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: black
#
# Question 3
# The defendant is a male aged 23. They have been charged with: Possession of Cannabis/Marijuana. This crime is classified as a misdemeanor. They have been convicted of 2 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: hispanic
#
# Question 4
# The defendant is a female aged 27. They have been charged with: Battery. This crime is classified as a misdemeanor. They have been convicted of 0 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: black
#
# Question 5
# The defendant is a female aged 21. They have been charged with: Forgery. This crime is classified as a felony. They have been convicted of 0 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: black
#
# Question 6
# The defendant is a male aged 24. They have been charged with: Child Molestation. This crime is classified as a felony. They have been convicted of 2 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: hispanic
#
# Question 7
# The defendant is a male aged 67. They have been charged with: Battery. This crime is classified as a misdemeanor. They have been convicted of 0 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: white
#
# Question 8
# The defendant is a male aged 22. They have been charged with: Burglary. This crime is classified as a felony. They have been convicted of 0 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: black
#
# Question 9
# The defendant is a male aged 23. They have been charged with: Possession of a Controlled Substance. This crime is classified as a felony. They have been convicted of 6 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: white
#
# Question 10
# The defendant is a male aged 26. They have been charged with: Criminal Damage of more than $1000. This crime is classified as a felony. They have been convicted of 3 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: black
#
# Question 11
# The defendant is a male aged 41. They have been charged with: Possession of a Controlled Substance. This crime is classified as a felony. They have been convicted of 0 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: white
#
# Question 12
# The defendant is a male aged 22. They have been charged with: Possession of Cannabis/Marijuana. This crime is classified as a felony. They have been convicted of 0 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: black
#
# Question 13
# The defendant is a male aged 24. They have been charged with: Burglary. This crime is classified as a felony. They have been convicted of 0 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: black
#
# Question 14
# The defendant is a male aged 26. They have been charged with: Burglary. This crime is classified as a felony. They have been convicted of 5 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: black
#
# Question 15
# The defendant is a male aged 47. They have been charged with: Possession of Cocaine. This crime is classified as a felony. They have been convicted of 4 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: black
#
# Question 16
# The defendant is a male aged 31. They have been charged with: Possession of Oxycodone. This crime is classified as a felony. They have been convicted of 17 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: white
#
# Question 17
# The defendant is a female aged 32. They have been charged with: Possession of Heroin. This crime is classified as a felony. They have been convicted of 2 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: white
#
# Question 18
# The defendant is a male aged 26. They have been charged with: Assault. This crime is classified as a misdemeanor. They have been convicted of 5 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# no
# This person's race is: white
#
# Question 19
# The defendant is a male aged 52. They have been charged with: Driving Under the Influence. This crime is classified as a misdemeanor. They have been convicted of 15 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: black
#
# Question 20
# The defendant is a female aged 53. They have been charged with: Possession of Cocaine. This crime is classified as a felony. They have been convicted of 6 prior crimes. They have 0 juvenile felony charges and 0 juvenile misdemeanor charges on their record.
#
# Do you think this person will commit another crime within 2 years?
# yes
# This person's race is: white

# %%
tab.iloc[arr]
# Out:
#      block_num     id  race  sex  age  juv_fel_count  juv_misd_count  \
# 520         11   8258     2    0   26              0               0
# 792         16   4408     2    0   42              0               0
# 835         17   1004     3    0   23              0               0
# 871         18   9277     2    1   27              0               0
# 855         18   8358     2    1   21              0               0
# 79           2   9634     3    0   24              0               0
# 944         19  10544     1    0   67              0               0
# 906         19   6805     2    0   22              0               0
# 350          8   8045     1    0   23              0               0
# 948         19   2128     2    0   26              0               0
# 866         18   8205     1    0   41              0               0
# 53           2   1103     2    0   22              0               0
# 578         12   1943     2    0   24              0               0
# 738         15   9136     2    0   26              0               0
# 526         11   1611     2    0   47              0               0
# 802         17   6056     1    0   31              0               0
# 752         16   9106     1    1   32              0               0
# 280          6   7259     1    0   26              0               0
# 655         14   2220     2    0   52              0               0
# 228          5   6586     1    1   53              0               0
#
#      priors_count  charge_id  charge_degree (misd/fel)  compas_decile_score  \
# 520             6         55                         1                    7
# 792             3        306                         1                    1
# 835             2        283                         0                    6
# 871             0         45                         0                    3
# 855             0        418                         1                    6
# 79              2        212                         1                    3
# 944             0         45                         0                    1
# 906             0         59                         1                    3
# 350             6        297                         1                    9
# 948             3         90                         1                    3
# 866             0        253                         1                    2
# 53              0        246                         1                    8
# 578             0        292                         1                    3
# 738             5         60                         1                    4
# 526             4        306                         1                    3
# 802            17        319                         1                    8
# 752             2        354                         1                    2
# 280             5         31                         0                    5
# 655            15        128                         0                    4
# 228             6        306                         1                    5
#
#      two_year_recid
# 520               1
# 792               0
# 835               1
# 871               0
# 855               0
# 79                0
# 944               0
# 906               1
# 350               1
# 948               1
# 866               1
# 53                0
# 578               1
# 738               0
# 526               0
# 802               1
# 752               1
# 280               0
# 655               1
# 228               1
